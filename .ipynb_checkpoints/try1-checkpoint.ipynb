# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from imageio import imread

import torch
from torchvision import datasets,transforms,models
from torch import nn
import torch.nn.functional as F
from torch.utils import data
from myDatasets import *

# %%
data_dir='/Users/nithin_rao/MyFiles/MS/USC/Internships/BrainCorp/find_phone_task_4/find_phone/'

# %%
label_ids = !cut -f 1 -d ' ' $data_dir/labels.txt
label_loc_x = !cut -f 2 -d ' ' $data_dir/labels.txt
label_loc_y = !cut -f 3 -d ' ' $data_dir/labels.txt
label_loc_x = np.asarray(label_loc_x,dtype=np.float32).reshape(-1,1)
label_loc_y = np.asarray(label_loc_y,dtype=np.float32).reshape(-1,1)
labels = np.hstack((label_loc_x,label_loc_y)) 

filenames = [data_dir+file for file in label_ids]

# %%
tfms = transforms.Compose([transforms.ToPILImage(),
                           transforms.Resize((224,224)),
                            transforms.ToTensor(),
                          transforms.Normalize((0.485, 0.456, 0.406),
                                               (0.229, 0.224, 0.225))])

train_per = 0.7
len_filenames = len(filenames)
train_filenames = filenames[:int(train_per*len_filenames)]
valid_filenames = filenames[int(train_per*len_filenames):]

train_labels = labels[:int(train_per*len_filenames)]
valid_labels = labels[int(train_per*len_filenames):]

train_dset_natural = ImageDataset(train_filenames,train_labels,tfms=tfms)
train_dset_hflip = ImageDataset_hflip(train_filenames,train_labels,tfms=tfms)
train_dset_vflip = ImageDataset_vflip(train_filenames,train_labels,tfms=tfms)

train_dataset = data.ConcatDataset([train_dset_natural,train_dset_hflip,train_dset_vflip])
valid_dataset = ImageDataset(valid_filenames,valid_labels,tfms=tfms)

train_loader = data.DataLoader(train_dataset,batch_size=1,shuffle=True)
valid_loader = data.DataLoader(valid_dataset,batch_size=1,shuffle=True)

# %%
def imshow(image):
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = image.numpy().transpose((1, 2, 0))
    image = std * image + mean
    image = np.clip(image, 0, 1)
    plt.imshow(image)

# %%
train_loader = data.DataLoader(train_dataset,batch_size=16,shuffle=True)

# %%
x,y = next(iter(train_loader))

# %%
imshow(x[0])
plt.plot(y[0,0],y[0,1],marker='*',color='r')
plt.show()

# %%
model = models.resnet50(pretrained=True)

# %%
for param in model.parameters():
    param.requires_grad=False

# %%
from collections import OrderedDict

regressor=nn.Sequential(OrderedDict([
#                           ('dropout1',nn.Dropout(0.6)),
                          ('fc1', nn.Linear(2048, 50)),
                          ('relu', nn.ReLU()),
#                           ('dropout2',nn.Dropout(0.6)),
#                           ('fc2', nn.Linear(512, 50)),
#                           ('relu2', nn.ReLU()),
                          ('fc3', nn.Linear(50, 2))
#                           ('output', nn.Sigmoid())
                          ]))

# %%
# print(model)

# %%
model.fc = regressor

# %%
# print(model)

# %%
criterion = nn.L1Loss()
learning_rate = 2e-3
optimizer = torch.optim.Adam(model.fc.parameters())

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def distance(labels,predict,steps=1):
    dist= torch.sum((labels-predict)**2,1)
    mask = 0*dist;
    mask[dist<=0.05]=1
    if steps % 5==0:
        print(predict)
    return mask

def evaluate(model, dataloader, criterion, device):
    loss = 0
    accuracy = 0
    with torch.no_grad():
        for img,labels in iter(dataloader):
                img,labels = img.to(device), labels.to(device)
                
                output = model.forward(img)
                loss += criterion(output,labels).item()
                
                accuracy += distance(output,labels).mean()
    return loss,accuracy

# %%
import pdb

# %%
model.to(device)
epochs = 5
print_every = 2

steps = 0
running_loss=0
train_accuracy=0
valid_loss_min = np.Inf

for e in range(epochs):
    
    model.train()
    
    for images,labels in iter(train_loader):
        images,labels = images.to(device),labels.to(device)
        
        steps+=1
        optimizer.zero_grad()
        
        output = model.forward(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
#         pdb.set_trace()
        train_accuracy += distance(labels,output,steps).mean()
        
        if steps % print_every==0 :
            model.eval()
            
            with torch.no_grad():
                valid_loss, valid_accuracy= evaluate(model,valid_loader,
                                                    criterion,
                                                    device)
                print("Epoch: {}/{}.. ".format(e+1, epochs),
                        "Training Loss: {:.3f}.. ".format(running_loss/print_every),
                        "Training Accuracy: {:.3f}".format(train_accuracy/print_every),
                        "Validation Loss: {:.3f}.. ".format(valid_loss/len(valid_loader)),
                        "Validation Accuracy: {:.3f}".format(valid_accuracy/len(valid_loader)))
                
#           if valid_loss < valid_loss_min:
#               savemodel()
#               valid_loss_min = valid_loss
            running_loss=0
            train_accuracy=0
            model.train()

print("\n Training Done")
# Out:
# Epoch: 1/5..  Training Loss: 84.189..  Training Accuracy: 0.000 Validation Loss: 73.180..  Validation Accuracy: 0.000
# Epoch: 1/5..  Training Loss: 78.976..  Training Accuracy: 0.000 Validation Loss: 70.153..  Validation Accuracy: 0.000
# tensor([[24.0630, 27.8237],
#         [30.9656, 35.8399],
#         [27.6207, 31.9106],
#         [26.5543, 30.6567],
#         [26.1462, 30.2839],
#         [28.6887, 33.1437],
#         [29.9892, 34.6726],
#         [32.8195, 37.8689],
#         [29.2768, 33.8672],
#         [30.6944, 35.5810],
#         [31.2702, 36.1798],
#         [28.0210, 32.5470],
#         [34.0311, 39.2661],
#         [33.9136, 39.1272],
#         [29.0075, 33.4759],
#         [30.3935, 35.0984]], grad_fn=<AddmmBackward>)
# Epoch: 1/5..  Training Loss: 87.306..  Training Accuracy: 0.000 Validation Loss: 67.136..  Validation Accuracy: 0.000
# Epoch: 1/5..  Training Loss: 87.200..  Training Accuracy: 0.000 Validation Loss: 64.132..  Validation Accuracy: 0.000
# tensor([[42.0636, 48.2664],
#         [40.3185, 46.1992],
#         [46.0742, 52.7562],
#         [41.5270, 47.5475],
#         [33.7082, 38.6549],
#         [31.3989, 35.8704],
#         [45.7439, 52.4336],
#         [36.2071, 41.5112],
#         [32.6810, 37.6450],
#         [39.0982, 44.8312],
#         [34.9127, 40.2175],
#         [34.4679, 39.6639],
#         [39.6066, 45.4085],
#         [42.1387, 48.3369],
#         [36.3222, 41.6604],
#         [29.5586, 33.8624]], grad_fn=<AddmmBackward>)
# Epoch: 1/5..  Training Loss: 59.856..  Training Accuracy: 0.000 Validation Loss: 61.280..  Validation Accuracy: 0.000
# Epoch: 1/5..  Training Loss: 71.268..  Training Accuracy: 0.000 Validation Loss: 58.326..  Validation Accuracy: 0.000
# Epoch: 1/5..  Training Loss: 68.468..  Training Accuracy: 0.000 Validation Loss: 55.657..  Validation Accuracy: 0.000
# tensor([[44.3077, 50.4948],
#         [51.6853, 58.9372],
#         [45.6015, 51.9473],
#         [44.7243, 51.0186],
#         [44.4773, 50.6458],
#         [53.0029, 60.3961],
#         [49.6363, 56.5036],
#         [42.1240, 48.1057],
#         [50.5191, 57.4202],
#         [47.0603, 53.5536],
#         [49.1039, 56.0712],
#         [49.7075, 56.6473],
#         [35.2440, 40.2880],
#         [49.4944, 56.3037],
#         [48.3522, 55.1891],
#         [52.1463, 59.4962]], grad_fn=<AddmmBackward>)
# Epoch: 1/5..  Training Loss: 75.423..  Training Accuracy: 0.000 Validation Loss: 53.184..  Validation Accuracy: 0.000
# Epoch: 2/5..  Training Loss: 60.208..  Training Accuracy: 0.000 Validation Loss: 50.583..  Validation Accuracy: 0.000
# tensor([[64.1889, 72.6430],
#         [65.3545, 74.0338],
#         [60.5916, 68.6431],
#         [53.8065, 60.9292],
#         [48.5593, 55.0103],
#         [53.9305, 61.0245],
#         [58.3020, 66.0551],
#         [57.1029, 64.7331],
#         [50.7145, 57.5039],
#         [51.4316, 58.2322],
#         [56.2908, 63.7486],
#         [66.8719, 75.7449],
#         [58.8575, 66.8113],
#         [52.6312, 59.7350],
#         [61.0016, 68.9620],
#         [61.3592, 69.4701]], grad_fn=<AddmmBackward>)
# Epoch: 2/5..  Training Loss: 57.364..  Training Accuracy: 0.000 Validation Loss: 48.415..  Validation Accuracy: 0.000
# Epoch: 2/5..  Training Loss: 44.683..  Training Accuracy: 0.000 Validation Loss: 46.501..  Validation Accuracy: 0.000
# Epoch: 2/5..  Training Loss: 63.784..  Training Accuracy: 0.000 Validation Loss: 44.829..  Validation Accuracy: 0.000
# tensor([[40.7288, 45.9064],
#         [68.2595, 76.7749],
#         [72.4212, 81.5091],
#         [67.7209, 76.2898],
#         [76.1393, 85.8839],
#         [54.4292, 61.1729],
#         [60.3455, 67.9447],
#         [66.8953, 75.2206],
#         [64.1597, 72.3249],
#         [83.1377, 93.7469],
#         [70.6143, 79.4157],
#         [75.2577, 84.9039],
#         [61.7873, 69.6372],
#         [78.3705, 88.2720],
#         [71.1931, 79.9627],
#         [64.8012, 73.1684]], grad_fn=<AddmmBackward>)
# Epoch: 2/5..  Training Loss: 61.223..  Training Accuracy: 0.000 Validation Loss: 44.209..  Validation Accuracy: 0.000
# Epoch: 2/5..  Training Loss: 57.628..  Training Accuracy: 0.000 Validation Loss: 43.603..  Validation Accuracy: 0.000
# tensor([[76.9094, 86.1925],
#         [60.6468, 68.0108],
#         [75.3614, 84.4368],
#         [72.4811, 81.1472],
#         [84.6216, 94.8851],
#         [67.0366, 75.2355],
#         [87.0430, 97.6331],
#         [84.0955, 94.2770],
#         [71.8169, 80.5735],
#         [87.1750, 97.7343],
#         [86.4466, 96.9967],
#         [78.6010, 88.1017],
#         [75.8009, 84.9865],
#         [72.0813, 80.9972],
#         [75.8223, 85.1965],
#         [65.4956, 73.5913]], grad_fn=<AddmmBackward>)
# Epoch: 2/5..  Training Loss: 50.075..  Training Accuracy: 0.000 Validation Loss: 43.197..  Validation Accuracy: 0.000
# Epoch: 2/5..  Training Loss: 47.384..  Training Accuracy: 0.000 Validation Loss: 42.800..  Validation Accuracy: 0.000
# Epoch: 2/5..  Training Loss: 54.494..  Training Accuracy: 0.000 Validation Loss: 42.865..  Validation Accuracy: 0.000
# tensor([[ 93.1713, 104.0628],
#         [ 91.6513, 102.2932],
#         [ 75.6816,  84.7099],
#         [ 86.2743,  96.1990],
#         [ 92.5170, 103.4465],
#         [ 98.5815, 110.2898],
#         [ 61.5849,  68.6479],
#         [ 95.9627, 107.0818],
#         [ 80.9321,  90.3328],
#         [ 92.8610, 103.5954],
#         [ 80.0823,  89.2645],
#         [ 80.7185,  90.0935],
#         [101.7635, 113.4002],
#         [ 75.4720,  84.2905],
#         [ 85.8594,  96.0192],
#         [ 79.3189,  88.6408]], grad_fn=<AddmmBackward>)
# Epoch: 3/5..  Training Loss: 49.329..  Training Accuracy: 0.000 Validation Loss: 42.671..  Validation Accuracy: 0.000
# Epoch: 3/5..  Training Loss: 46.586..  Training Accuracy: 0.000 Validation Loss: 42.754..  Validation Accuracy: 0.000
# tensor([[100.2736, 110.5456],
#         [106.6887, 117.4084],
#         [109.1772, 120.2963],
#         [ 91.6688, 100.8782],
#         [ 96.3387, 106.0914],
#         [ 85.3627,  93.9903],
#         [ 98.2670, 108.0539],
#         [104.6666, 115.4009],
#         [ 92.8598, 102.1623],
#         [ 95.5686, 105.3896],
#         [ 89.4728,  98.4967],
#         [ 88.6063,  97.4056],
#         [ 89.8188,  99.2017],
#         [ 84.4464,  92.7625],
#         [ 82.7547,  91.1796],
#         [107.8851, 118.7186]], grad_fn=<AddmmBackward>)
# Epoch: 3/5..  Training Loss: 45.724..  Training Accuracy: 0.000 Validation Loss: 43.180..  Validation Accuracy: 0.000
# Epoch: 3/5..  Training Loss: 53.359..  Training Accuracy: 0.000 Validation Loss: 42.973..  Validation Accuracy: 0.000
# Epoch: 3/5..  Training Loss: 47.442..  Training Accuracy: 0.000 Validation Loss: 43.018..  Validation Accuracy: 0.000
# tensor([[ 88.6312,  95.4140],
#         [ 74.9424,  81.0476],
#         [ 88.8420,  95.7956],
#         [104.1984, 112.4436],
#         [117.6894, 126.9918],
#         [107.6400, 116.1981],
#         [103.8208, 112.2482],
#         [ 85.6114,  92.3862],
#         [115.5590, 124.6780],
#         [103.3011, 111.3056],
#         [107.0196, 115.4810],
#         [107.8951, 116.2867],
#         [100.8924, 108.8495],
#         [106.3702, 114.7366],
#         [123.7810, 133.5507],
#         [ 88.4220,  95.2601]], grad_fn=<AddmmBackward>)
# Epoch: 3/5..  Training Loss: 51.249..  Training Accuracy: 0.000 Validation Loss: 43.232..  Validation Accuracy: 0.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-dc5da7595a7e> in <module>()
#      18         optimizer.zero_grad()
#      19
# ---> 20         output = model.forward(images)
#      21         loss = criterion(output, labels)
#      22         loss.backward()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#     145         x = self.layer2(x)
#     146         x = self.layer3(x)
# --> 147         x = self.layer4(x)
#     148
#     149         x = self.avgpool(x)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#      78         out = self.relu(out)
#      79
# ---> 80         out = self.conv2(out)
#      81         out = self.bn2(out)
#      82         out = self.relu(out)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
    output = model.forward(x[1].unsqueeze(0))

# %%
output

# %%
y[1]

# %%
for i in range(16):
    with torch.no_grad():
        output = model.forward(x[i].unsqueeze(0))
    imshow(x[i])
    plt.plot(y[i,0],y[i,1],marker='*',color='r')
    print(output)
    plt.plot(output[0,0],output[0,1],marker='*',color='b')
    plt.show()

# %%
output
